# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread('data/cut/photo_2018-09-17_14-18-00.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
th = cv2.adaptiveThreshold(gray, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 15, 5)

# ищем контуры и складируем их в переменную contours
contours, hierarchy = cv2.findContours(th, cv2.RETR_LIST , cv2.CHAIN_APPROX_SIMPLE)
cv2.drawContours(img, contours, -1, (255, 0, 0), 3, cv2.LINE_AA, hierarchy, 1)
cv2.imshow('contours', img) # выводим итоговое изображение в окно
print(contours, hierarchy)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# [array([[[254, 463]],
#
#        [[255, 462]],
#
#        [[256, 463]],
#
#        [[255, 464]]], dtype=int32), array([[[153, 463]],
#
#        [[154, 462]],
#
#        [[155, 463]],
#
#        [[154, 464]]], dtype=int32), array([[[135, 463]],
#
#        [[136, 462]],
#
#        [[137, 463]],
#
#        [[136, 464]]], dtype=int32), array([[[  3, 456]],
#
#        [[  4, 455]],
#
#        [[  6, 455]],
#
#        [[  7, 456]],
#
#        [[  6, 457]],
#
#        [[  4, 457]]], dtype=int32), array([[[115, 454]],
#
#        [[116, 453]],
#
#        [[117, 453]],
#
#        [[118, 454]],
#
#        [[117, 455]],
#
#        [[116, 455]]], dtype=int32), array([[[110, 453]],
#
#        [[111, 452]],
#
#        [[112, 452]],
#
#        [[113, 453]],
#
#        [[112, 454]],
#
#        [[111, 454]]], dtype=int32), array([[[159, 450]],
#
#        [[160, 449]],
#
#        [[161, 449]],
#
#        [[162, 450]],
#
#        [[161, 451]],
#
#        [[160, 451]]], dtype=int32), array([[[670, 447]],
#
#        [[671, 446]],
#
#        [[672, 447]],
#
#        [[671, 448]]], dtype=int32), array([[[225, 447]],
#
#        [[226, 446]],
#
#        [[227, 447]],
#
#        [[226, 448]]], dtype=int32), array([[[ 20, 444]],
#
#        [[ 21, 445]],
#
#        [[ 40, 445]],
#
#        [[ 41, 444]],
#
#        [[ 92, 444]],
#
#        [[ 93, 445]],
#
#        [[ 95, 445]],
#
#        [[ 96, 444]],
#
#        [[ 98, 444]],
#
#        [[ 99, 445]],
#
#        [[110, 445]],
#
#        [[111, 446]],
#
#        [[112, 445]],
#
#        [[113, 445]],
#
#        [[114, 446]],
#
#        [[123, 446]],
#
#        [[124, 447]],
#
#        [[125, 446]],
#
#        [[126, 447]],
#
#        [[131, 447]],
#
#        [[132, 448]],
#
#        [[139, 448]],
#
#        [[140, 449]],
#
#        [[149, 449]],
#
#        [[150, 450]],
#
#        [[157, 450]],
#
#        [[159, 452]],
#
#        [[159, 453]],
#
#        [[158, 454]],
#
#        [[153, 454]],
#
#        [[152, 453]],
#
#        [[148, 453]],
#
#        [[147, 452]],
#
#        [[142, 452]],
#
#        [[141, 451]],
#
#        [[140, 451]],
#
#        [[139, 452]],
#
#        [[137, 452]],
#
#        [[136, 451]],
#
#        [[131, 451]],
#
#        [[130, 450]],
#
#        [[122, 450]],
#
#        [[121, 449]],
#
#        [[120, 449]],
#
#        [[119, 450]],
#
#        [[118, 449]],
#
#        [[111, 449]],
#
#        [[110, 448]],
#
#        [[ 93, 448]],
#
#        [[ 92, 447]],
#
#        [[ 43, 447]],
#
#        [[ 42, 448]],
#
#        [[ 41, 447]],
#
#        [[ 38, 447]],
#
#        [[ 37, 448]],
#
#        [[ 19, 448]],
#
#        [[ 18, 447]],
#
#        [[ 18, 446]]], dtype=int32), array([[[ 11, 442]],
#
#        [[ 12, 441]],
#
#        [[ 13, 442]],
#
#        [[ 12, 443]]], dtype=int32), array([[[124, 441]],
#
#        [[125, 440]],
#
#        [[126, 441]],
#
#        [[125, 442]]], dtype=int32), array([[[103, 441]],
#
#        [[104, 440]],
#
#        [[106, 440]],
#
#        [[107, 441]],
#
#        [[106, 442]],
#
#        [[104, 442]]], dtype=int32), array([[[ 10, 441]],
#
#        [[ 11, 440]],
#
#        [[ 12, 441]],
#
#        [[ 11, 442]]], dtype=int32), array([[[674, 440]],
#
#        [[675, 439]],
#
#        [[676, 440]],
#
#        [[675, 441]]], dtype=int32), array([[[108, 440]],
#
#        [[109, 439]],
#
#        [[110, 440]],
#
#        [[109, 441]]], dtype=int32), array([[[ 24, 440]],
#
#        [[ 25, 439]],
#
#        [[ 26, 440]],
#
#        [[ 25, 441]]], dtype=int32), array([[[ 46, 439]],
#
#        [[ 47, 438]],
#
#        [[ 48, 438]],
#
#        [[ 49, 439]],
#
#        [[ 48, 440]],
#
#        [[ 47, 440]]], dtype=int32), array([[[112, 438]],
#
#        [[113, 437]],
#
#        [[114, 438]],
#
#        [[113, 439]]], dtype=int32), array([[[ 92, 438]],
#
#        [[ 93, 437]],
#
#        [[ 94, 437]],
#
#        [[ 95, 438]],
#
#        [[ 94, 439]],
#
#        [[ 93, 439]]], dtype=int32), array([[[ 86, 438]],
#
#        [[ 87, 437]],
#
#        [[ 88, 438]],
#
#        [[ 87, 439]]], dtype=int32), array([[[129, 436]],
#
#        [[130, 436]],
#
#        [[131, 437]],
#
#        [[131, 439]],
#
#        [[132, 440]],
#
#        [[131, 441]],
#
#        [[129, 441]],
#
#        [[128, 442]],
#
#        [[127, 441]],
#
#        [[127, 438]]], dtype=int32), array([[[ 43, 437]],
#
#        [[ 44, 436]],
#
#        [[ 45, 437]],
#
#        [[ 44, 438]]], dtype=int32), array([[[124, 435]],
#
#        [[125, 434]],
#
#        [[126, 435]],
#
#        [[125, 436]]], dtype=int32), array([[[420, 434]],
#
#        [[421, 433]],
#
#        [[422, 434]],
#
#        [[421, 435]]], dtype=int32), array([[[625, 432]],
#
#        [[626, 431]],
#
#        [[627, 432]],
#
#        [[626, 433]]], dtype=int32), array([[[611, 432]],
#
#        [[612, 431]],
#
#        [[614, 431]],
#
#        [[615, 432]],
#
#        [[614, 433]],
#
#        [[612, 433]]], dtype=int32), array([[[541, 432]],
#
#        [[542, 431]],
#
#        [[545, 431]],
#
#        [[546, 432]],
#
#        [[545, 433]],
#
#        [[542, 433]]], dtype=int32), array([[[192, 426]],
#
#        [[193, 425]],
#
#        [[194, 426]],
#
#        [[193, 427]]], dtype=int32), array([[[193, 425]],
#
#        [[194, 424]],
#
#        [[195, 425]],
#
#        [[194, 426]]], dtype=int32), array([[[420, 424]],
#
#        [[421, 423]],
#
#        [[422, 424]],
#
#        [[421, 425]]], dtype=int32), array([[[110, 424]],
#
#        [[111, 423]],
#
#        [[112, 424]],
#
#        [[111, 425]]], dtype=int32), array([[[120, 423]],
#
#        [[121, 422]],
#
#        [[123, 422]],
#
#        [[124, 423]],
#
#        [[123, 424]],
#
#        [[121, 424]]], dtype=int32), array([[[ 18, 423]],
#
#        [[ 19, 422]],
#
#        [[ 20, 423]],
#
#        [[ 19, 424]]], dtype=int32), array([[[106, 422]],
#
#        [[107, 421]],
#
#        [[108, 422]],
#
#        [[107, 423]]], dtype=int32), array([[[767, 421]],
#
#        [[768, 420]],
#
#        [[769, 421]],
#
#        [[769, 422]],
#
#        [[768, 423]],
#
#        [[767, 422]]], dtype=int32), array([[[118, 421]],
#
#        [[119, 420]],
#
#        [[120, 420]],
#
#        [[121, 421]],
#
#        [[121, 422]],
#
#        [[120, 423]],
#
#        [[119, 423]],
#
#        [[118, 422]]], dtype=int32), array([[[121, 420]],
#
#        [[122, 419]],
#
#        [[123, 420]],
#
#        [[122, 421]]], dtype=int32), array([[[785, 419]],
#
#        [[786, 418]],
#
#        [[787, 419]],
#
#        [[788, 418]],
#
#        [[790, 418]],
#
#        [[791, 419]],
#
#        [[791, 420]],
#
#        [[789, 422]],
#
#        [[788, 422]],
#
#        [[787, 421]],
#
#        [[786, 422]],
#
#        [[786, 423]],
#
#        [[785, 424]],
#
#        [[784, 424]],
#
#        [[783, 423]],
#
#        [[783, 420]],
#
#        [[784, 419]]], dtype=int32), array([[[106, 419]],
#
#        [[107, 418]],
#
#        [[108, 419]],
#
#        [[107, 420]]], dtype=int32), array([[[ 24, 419]],
#
#        [[ 25, 418]],
#
#        [[ 26, 418]],
#
#        [[ 27, 419]],
#
#        [[ 27, 420]],
#
#        [[ 26, 421]]], dtype=int32), array([[[ 17, 419]],
#
#        [[ 18, 418]],
#
#        [[ 19, 419]],
#
#        [[ 18, 420]]], dtype=int32), array([[[777, 417]],
#
#        [[778, 418]],
#
#        [[778, 423]],
#
#        [[777, 424]],
#
#        [[775, 424]],
#
#        [[774, 423]],
#
#        [[774, 421]],
#
#        [[775, 420]],
#
#        [[775, 419]]], dtype=int32), array([[[ 59, 418]],
#
#        [[ 60, 417]],
#
#        [[ 61, 418]],
#
#        [[ 60, 419]]], dtype=int32), array([[[ 21, 417]],
#
#        [[ 23, 419]],
#
#        [[ 21, 421]],
#
#        [[ 20, 421]],
#
#        [[ 19, 420]],
#
#        [[ 19, 419]]], dtype=int32), array([[[ 53, 417]],
#
#        [[ 54, 416]],
#
#        [[ 55, 417]],
#
#        [[ 54, 418]]], dtype=int32), array([[[ 80, 416]],
#
#        [[ 81, 415]],
#
#        [[ 82, 416]],
#
#        [[ 81, 417]]], dtype=int32), array([[[331, 415]],
#
#        [[332, 414]],
#
#        [[333, 414]],
#
#        [[334, 415]],
#
#        [[333, 416]],
#
#        [[332, 416]]], dtype=int32), array([[[ 69, 415]],
#
#        [[ 69, 418]],
#
#        [[ 68, 419]],
#
#        [[ 68, 422]],
#
#        [[ 67, 423]],
#
#        [[ 67, 425]],
#
#        [[ 68, 425]],
#
#        [[ 69, 426]],
#
#        [[ 71, 426]],
#
#        [[ 72, 427]],
#
#        [[ 73, 427]],
#
#        [[ 74, 428]],
#
#        [[ 77, 428]],
#
#        [[ 77, 426]],
#
#        [[ 76, 425]],
#
#        [[ 76, 424]],
#
#        [[ 75, 423]],
#
#        [[ 75, 422]],
#
#        [[ 72, 419]],
#
#        [[ 72, 418]]], dtype=int32), array([[[ 61, 415]],
#
#        [[ 62, 414]],
#
#        [[ 63, 415]],
#
#        [[ 62, 416]]], dtype=int32), array([[[351, 414]],
#
#        [[352, 413]],
#
#        [[353, 414]],
#
#        [[353, 415]],
#
#        [[352, 416]],
#
#        [[351, 415]]], dtype=int32), array([[[  8, 414]],
#
#        [[  9, 413]],
#
#        [[ 11, 413]],
#
#        [[ 12, 414]],
#
#        [[ 11, 415]],
#
#        [[  9, 415]]], dtype=int32), array([[[ 61, 412]],
#
#        [[ 62, 411]],
#
#        [[ 63, 412]],
#
#        [[ 62, 413]]], dtype=int32), array([[[ 54, 412]],
#
#        [[ 55, 411]],
#
#        [[ 56, 412]],
#
#        [[ 55, 413]]], dtype=int32), array([[[  7, 412]],
#
#        [[  8, 411]],
#
#        [[  9, 412]],
#
#        [[  8, 413]]], dtype=int32), array([[[790, 411]],
#
#        [[791, 410]],
#
#        [[793, 412]],
#
#        [[792, 413]],
#
#        [[791, 413]],
#
#        [[790, 412]]], dtype=int32), array([[[ 88, 411]],
#
#        [[ 88, 413]],
#
#        [[ 87, 414]],
#
#        [[ 87, 419]],
#
#        [[ 89, 417]],
#
#        [[ 91, 417]],
#
#        [[ 94, 414]],
#
#        [[ 93, 413]],
#
#        [[ 93, 412]],
#
#        [[ 92, 412]],
#
#        [[ 91, 411]]], dtype=int32), array([[[ 72, 411]],
#
#        [[ 73, 410]],
#
#        [[ 74, 411]],
#
#        [[ 73, 412]]], dtype=int32), array([[[114, 410]],
#
#        [[115, 409]],
#
#        [[118, 409]],
#
#        [[121, 412]],
#
#        [[121, 413]],
#
#        [[117, 417]],
#
#        [[116, 417]],
#
#        [[115, 418]],
#
#        [[114, 418]],
#
#        [[113, 417]],
#
#        [[113, 416]],
#
#        [[114, 415]],
#
#        [[115, 415]],
#
#        [[117, 413]],
#
#        [[117, 412]],
#
#        [[113, 412]],
#
#        [[113, 413]],
#
#        [[112, 414]],
#
#        [[110, 414]],
#
#        [[105, 419]],
#
#        [[106, 420]],
#
#        [[104, 422]],
#
#        [[104, 425]],
#
#        [[106, 427]],
#
#        [[106, 428]],
#
#        [[107, 428]],
#
#        [[108, 429]],
#
#        [[109, 429]],
#
#        [[110, 430]],
#
#        [[111, 430]],
#
#        [[112, 431]],
#
#        [[113, 431]],
#
#        [[114, 432]],
#
#        [[118, 432]],
#
#        [[119, 433]],
#
#        [[123, 433]],
#
#        [[124, 434]],
#
#        [[122, 436]],
#
#        [[118, 436]],
#
#        [[117, 435]],
#
#        [[113, 435]],
#
#        [[112, 434]],
#
#        [[111, 434]],
#
#        [[110, 433]],
#
#        [[108, 433]],
#
#        [[107, 432]],
#
#        [[106, 432]],
#
#        [[104, 430]],
#
#        [[103, 430]],
#
#        [[102, 429]],
#
#        [[102, 428]],
#
#        [[101, 427]],
#
#        [[101, 426]],
#
#        [[100, 425]],
#
#        [[100, 424]],
#
#        [[101, 423]],
#
#        [[101, 420]],
#
#        [[102, 419]],
#
#        [[102, 418]],
#
#        [[109, 411]],
#
#        [[110, 411]],
#
#        [[111, 410]]], dtype=int32), array([[[107, 410]],
#
#        [[108, 409]],
#
#        [[109, 410]],
#
#        [[108, 411]]], dtype=int32), array([[[ 96, 409]],
#
#        [[ 97, 408]],
#
#        [[ 98, 408]],
#
#        [[ 99, 409]],
#
#        [[ 98, 410]],
#
#        [[ 97, 410]]], dtype=int32), array([[[ 86, 408]],
#
#        [[ 92, 408]],
#
#        [[ 93, 409]],
#
#        [[ 94, 409]],
#
#        [[ 95, 410]],
#
#        [[ 96, 410]],
#
#        [[ 98, 412]],
#
#        [[ 97, 413]],
#
#        [[ 98, 414]],
#
#        [[ 96, 416]],
#
#        [[ 96, 417]],
#
#        [[ 95, 418]],
#
#        [[ 94, 418]],
#
#        [[ 93, 419]],
#
#        [[ 92, 419]],
#
#        [[ 91, 420]],
#
#        [[ 90, 420]],
#
#        [[ 89, 421]],
#
#        [[ 88, 421]],
#
#        [[ 88, 422]],
#
#        [[ 90, 422]],
#
#        [[ 91, 423]],
#
#        [[ 94, 423]],
#
#        [[ 96, 425]],
#
#        [[ 97, 425]],
#
#        [[ 99, 427]],
#
#        [[ 99, 428]],
#
#        [[100, 429]],
#
#        [[ 99, 430]],
#
#        [[ 99, 432]],
#
#        [[ 96, 435]],
#
#        [[ 94, 435]],
#
#        [[ 93, 436]],
#
#        [[ 85, 436]],
#
#        [[ 84, 435]],
#
#        [[ 84, 433]],
#
#        [[ 85, 432]],
#
#        [[ 86, 433]],
#
#        [[ 91, 433]],
#
#        [[ 92, 432]],
#
#        [[ 94, 432]],
#
#        [[ 95, 431]],
#
#        [[ 96, 431]],
#
#        [[ 96, 429]],
#
#        [[ 95, 429]],
#
#        [[ 94, 428]],
#
#        [[ 94, 427]],
#
#        [[ 93, 426]],
#
#        [[ 92, 427]],
#
#        [[ 90, 425]],
#
#        [[ 89, 425]],
#
#        [[ 88, 424]],
#
#        [[ 87, 425]],
#
#        [[ 89, 427]],
#
#        [[ 89, 428]],
#
#        [[ 88, 429]],
#
#        [[ 86, 429]],
#
#        [[ 85, 428]],
#
#        [[ 85, 427]],
#
#        [[ 84, 426]],
#
#        [[ 84, 410]]], dtype=int32), array([[[ 73, 408]],
#
#        [[ 74, 407]],
#
#        [[ 76, 409]],
#
#        [[ 76, 410]],
#
#        [[ 75, 411]],
#
#        [[ 73, 409]]], dtype=int32), array([[[433, 407]],
#
#        [[434, 406]],
#
#        [[435, 407]],
#
#        [[434, 408]]], dtype=int32), array([[[ 54, 407]],
#
#        [[ 55, 406]],
#
#        [[ 63, 406]],
#
#        [[ 64, 407]],
#
#        [[ 65, 407]],
#
#        [[ 66, 408]],
#
#        [[ 67, 407]],
#
#        [[ 68, 407]],
#
#        [[ 70, 409]],
#
#        [[ 70, 412]],
#
#        [[ 71, 412]],
#
#        [[ 72, 413]],
#
#        [[ 72, 414]],
#
#        [[ 78, 420]],
#
#        [[ 78, 421]],
#
#        [[ 79, 422]],
#
#        [[ 79, 424]],
#
#        [[ 80, 424]],
#
#        [[ 81, 425]],
#
#        [[ 80, 426]],
#
#        [[ 80, 427]],
#
#        [[ 81, 428]],
#
#        [[ 81, 429]],
#
#        [[ 79, 431]],
#
#        [[ 78, 431]],
#
#        [[ 77, 432]],
#
#        [[ 76, 431]],
#
#        [[ 72, 431]],
#
#        [[ 70, 429]],
#
#        [[ 67, 429]],
#
#        [[ 66, 428]],
#
#        [[ 65, 428]],
#
#        [[ 64, 427]],
#
#        [[ 63, 428]],
#
#        [[ 62, 428]],
#
#        [[ 61, 429]],
#
#        [[ 59, 427]],
#
#        [[ 59, 425]],
#
#        [[ 61, 423]],
#
#        [[ 64, 423]],
#
#        [[ 64, 422]],
#
#        [[ 65, 421]],
#
#        [[ 65, 420]],
#
#        [[ 66, 419]],
#
#        [[ 65, 418]],
#
#        [[ 66, 417]],
#
#        [[ 66, 412]],
#
#        [[ 64, 410]],
#
#        [[ 62, 410]],
#
#        [[ 61, 409]],
#
#        [[ 57, 409]],
#
#        [[ 53, 413]],
#
#        [[ 52, 413]],
#
#        [[ 51, 412]],
#
#        [[ 52, 411]],
#
#        [[ 52, 409]],
#
#        [[ 53, 408]],
#
#        [[ 54, 408]]], dtype=int32), array([[[327, 404]],
#
#        [[328, 405]],
#
#        [[328, 407]],
#
#        [[327, 408]],
#
#        [[326, 408]],
#
#        [[325, 407]],
#
#        [[325, 406]]], dtype=int32), array([[[425, 403]],
#
#        [[426, 402]],
#
#        [[427, 403]],
#
#        [[426, 404]]], dtype=int32), array([[[ 50, 403]],
#
#        [[ 51, 402]],
#
#        [[ 52, 403]],
#
#        [[ 51, 404]]], dtype=int32), array([[[ 54, 402]],
#
#        [[ 55, 401]],
#
#        [[ 56, 402]],
#
#        [[ 55, 403]]], dtype=int32), array([[[ 35, 401]],
#
#        [[ 36, 400]],
#
#        [[ 38, 400]],
#
#        [[ 40, 402]],
#
#        [[ 45, 402]],
#
#        [[ 46, 401]],
#
#        [[ 48, 401]],
#
#        [[ 49, 402]],
#
#        [[ 49, 403]],
#
#        [[ 46, 406]],
#
#        [[ 46, 407]],
#
#        [[ 45, 408]],
#
#        [[ 45, 411]],
#
#        [[ 46, 412]],
#
#        [[ 46, 415]],
#
#        [[ 47, 416]],
#
#        [[ 47, 417]],
#
#        [[ 48, 418]],
#
#        [[ 48, 419]],
#
#        [[ 50, 421]],
#
#        [[ 50, 422]],
#
#        [[ 52, 424]],
#
#        [[ 52, 426]],
#
#        [[ 53, 426]],
#
#        [[ 54, 427]],
#
#        [[ 54, 430]],
#
#        [[ 52, 432]],
#
#        [[ 51, 432]],
#
#        [[ 50, 433]],
#
#        [[ 46, 433]],
#
#        [[ 45, 432]],
#
#        [[ 42, 432]],
#
#        [[ 41, 431]],
#
#        [[ 40, 431]],
#
#        [[ 39, 430]],
#
#        [[ 38, 430]],
#
#        [[ 36, 428]],
#
#        [[ 36, 427]],
#
#        [[ 37, 426]],
#
#        [[ 39, 426]],
#
#        [[ 40, 427]],
#
#        [[ 41, 427]],
#
#        [[ 42, 428]],
#
#        [[ 43, 428]],
#
#        [[ 44, 429]],
#
#        [[ 47, 429]],
#
#        [[ 48, 430]],
#
#        [[ 50, 430]],
#
#        [[ 50, 428]],
#
#        [[ 48, 426]],
#
#        [[ 48, 425]],
#
#        [[ 47, 424]],
#
#        [[ 47, 423]],
#
#        [[ 45, 421]],
#
#        [[ 45, 420]],
#
#        [[ 44, 419]],
#
#        [[ 44, 418]],
#
#        [[ 43, 417]],
#
#        [[ 43, 415]],
#
#        [[ 42, 414]],
#
#        [[ 42, 407]],
#
#        [[ 43, 406]],
#
#        [[ 43, 405]],
#
#        [[ 38, 405]],
#
#        [[ 37, 404]],
#
#        [[ 36, 404]],
#
#        [[ 35, 403]]], dtype=int32), array([[[ 14, 395]],
#
#        [[ 15, 394]],
#
#        [[ 16, 394]],
#
#        [[ 17, 395]],
#
#        [[ 15, 397]],
#
#        [[ 14, 396]]], dtype=int32), array([[[  7, 395]],
#
#        [[  8, 394]],
#
#        [[ 10, 394]],
#
#        [[ 11, 395]],
#
#        [[ 11, 397]],
#
#        [[  9, 399]],
#
#        [[  9, 402]],
#
#        [[  8, 403]],
#
#        [[  8, 405]],
#
#        [[  9, 406]],
#
#        [[  9, 407]],
#
#        [[ 12, 407]],
#
#        [[ 12, 405]],
#
#        [[ 14, 403]],
#
#        [[ 14, 402]],
#
#        [[ 15, 401]],
#
#        [[ 15, 399]],
#
#        [[ 17, 397]],
#
#        [[ 18, 397]],
#
#        [[ 19, 398]],
#
#        [[ 19, 399]],
#
#        [[ 20, 400]],
#
#        [[ 19, 401]],
#
#        [[ 18, 401]],
#
#        [[ 18, 407]],
#
#        [[ 17, 408]],
#
#        [[ 18, 409]],
#
#        [[ 18, 415]],
#
#        [[ 17, 416]],
#
#        [[ 17, 422]],
#
#        [[ 15, 424]],
#
#        [[ 13, 424]],
#
#        [[ 12, 423]],
#
#        [[ 12, 421]],
#
#        [[ 13, 420]],
#
#        [[ 13, 419]],
#
#        [[ 14, 418]],
#
#        [[ 14, 414]],
#
#        [[ 15, 413]],
#
#        [[ 14, 412]],
#
#        [[ 14, 411]],
#
#        [[ 15, 410]],
#
#        [[ 15, 408]],
#
#        [[ 14, 408]],
#
#        [[ 12, 410]],
#
#        [[  8, 410]],
#
#        [[  5, 407]],
#
#        [[  5, 400]],
#
#        [[  6, 399]],
#
#        [[  6, 397]],
#
#        [[  7, 396]]], dtype=int32), array([[[ 17, 393]],
#
#        [[ 18, 392]],
#
#        [[ 19, 392]],
#
#        [[ 20, 393]],
#
#        [[ 19, 394]],
#
#        [[ 18, 394]]], dtype=int32), array([[[273, 392]],
#
#        [[274, 391]],
#
#        [[275, 392]],
#
#        [[274, 393]]], dtype=int32), array([[[ 10, 392]],
#
#        [[ 11, 391]],
#
#        [[ 12, 392]],
#
#        [[ 12, 393]],
#
#        [[ 11, 394]],
#
#        [[ 10, 393]]], dtype=int32), array([[[ 92, 383]],
#
#        [[ 93, 382]],
#
#        [[ 94, 383]],
#
#        [[ 93, 384]]], dtype=int32), array([[[121, 376]],
#
#        [[122, 375]],
#
#        [[123, 375]],
#
#        [[124, 376]],
#
#        [[123, 377]],
#
#        [[122, 377]]], dtype=int32), array([[[376, 375]],
#
#        [[377, 374]],
#
#        [[378, 375]],
#
#        [[377, 376]]], dtype=int32), array([[[363, 375]],
#
#        [[364, 374]],
#
#        [[365, 375]],
#
#        [[364, 376]]], dtype=int32), array([[[340, 375]],
#
#        [[341, 374]],
#
#        [[342, 374]],
#
#        [[343, 375]],
#
#        [[342, 376]],
#
#        [[341, 376]]], dtype=int32), array([[[303, 375]],
#
#        [[304, 374]],
#
#        [[305, 375]],
#
#        [[304, 376]]], dtype=int32), array([[[102, 375]],
#
#        [[103, 374]],
#
#        [[105, 374]],
#
#        [[106, 375]],
#
#        [[105, 376]],
#
#        [[103, 376]]], dtype=int32), array([[[374, 372]],
#
#        [[375, 371]],
#
#        [[376, 372]],
#
#        [[375, 373]]], dtype=int32), array([[[358, 368]],
#
#        [[359, 367]],
#
#        [[360, 367]],
#
#        [[361, 368]],
#
#        [[361, 369]],
#
#        [[362, 370]],
#
#        [[362, 372]],
#
#        [[360, 374]],
#
#        [[358, 372]]], dtype=int32), array([[[366, 364]],
#
#        [[367, 364]],
#
#        [[368, 365]],
#
#        [[368, 367]],
#
#        [[369, 368]],
#
#        [[369, 370]],
#
#        [[367, 372]],
#
#        [[366, 372]],
#
#        [[365, 371]],
#
#        [[365, 370]],
#
#        [[364, 369]],
#
#        [[364, 366]]], dtype=int32), array([[[348, 365]],
#
#        [[349, 364]],
#
#        [[351, 364]],
#
#        [[352, 365]],
#
#        [[352, 367]],
#
#        [[353, 368]],
#
#        [[353, 370]],
#
#        [[351, 372]],
#
#        [[350, 372]],
#
#        [[349, 371]],
#
#        [[349, 370]],
#
#        [[348, 369]]], dtype=int32), array([[[314, 364]],
#
#        [[315, 363]],
#
#        [[316, 363]],
#
#        [[317, 364]],
#
#        [[317, 365]],
#
#        [[318, 366]],
#
#        [[318, 367]],
#
#        [[317, 368]],
#
#        [[316, 367]],
#
#        [[315, 367]],
#
#        [[314, 366]]], dtype=int32), array([[[310, 364]],
#
#        [[309, 365]],
#
#        [[308, 365]],
#
#        [[308, 366]]], dtype=int32), array([[[376, 363]],
#
#        [[376, 364]],
#
#        [[377, 363]]], dtype=int32), array([[[381, 362]],
#
#        [[382, 361]],
#
#        [[385, 361]],
#
#        [[390, 366]],
#
#        [[389, 367]],
#
#        [[388, 367]],
#
#        [[387, 366]],
#
#        [[386, 366]],
#
#        [[385, 365]],
#
#        [[384, 365]],
#
#        [[384, 367]],
#
#        [[385, 368]],
#
#        [[384, 369]],
#
#        [[384, 370]],
#
#        [[385, 371]],
#
#        [[385, 372]],
#
#        [[384, 373]],
#
#        [[382, 373]],
#
#        [[381, 372]]], dtype=int32), array([[[386, 361]],
#
#        [[387, 360]],
#
#        [[388, 361]],
#
#        [[387, 362]]], dtype=int32), array([[[372, 361]],
#
#        [[373, 360]],
#
#        [[377, 360]],
#
#        [[379, 362]],
#
#        [[379, 365]],
#
#        [[380, 366]],
#
#        [[378, 368]],
#
#        [[377, 367]],
#
#        [[377, 368]],
#
#        [[375, 370]],
#
#        [[374, 370]],
#
#        [[373, 369]],
#
#        [[373, 368]],
#
#        [[372, 367]],
#
#        [[372, 366]],
#
#        [[371, 365]],
#
#        [[372, 364]]], dtype=int32), array([[[352, 361]],
#
#        [[353, 360]],
#
#        [[355, 360]],
#
#        [[356, 361]],
#
#        [[357, 361]],
#
#        [[358, 362]],
#
#        [[359, 361]],
#
#        [[360, 362]],
#
#        [[360, 363]],
#
#        [[362, 365]],
#
#        [[360, 367]],
#
#        [[359, 367]],
#
#        [[357, 365]],
#
#        [[356, 365]],
#
#        [[355, 364]],
#
#        [[353, 364]],
#
#        [[352, 363]]], dtype=int32), array([[[344, 360]],
#
#        [[345, 361]],
#
#        [[345, 367]],
#
#        [[346, 368]],
#
#        [[346, 372]],
#
#        [[344, 374]],
#
#        [[343, 373]],
#
#        [[343, 372]],
#
#        [[342, 371]],
#
#        [[342, 368]],
#
#        [[341, 367]],
#
#        [[342, 366]],
#
#        [[342, 362]]], dtype=int32), array([[[330, 360]],
#
#        [[331, 359]],
#
#        [[333, 359]],
#
#        [[334, 360]],
#
#        [[334, 362]],
#
#        [[335, 363]],
#
#        [[335, 369]],
#
#        [[337, 371]],
#
#        [[337, 372]],
#
#        [[335, 374]],
#
#        [[334, 374]],
#
#        [[333, 373]],
#
#        [[333, 371]],
#
#        [[332, 370]],
#
#        [[332, 364]],
#
#        [[331, 364]],
#
#        [[331, 369]],
#
#        [[330, 370]],
#
#        [[330, 371]],
#
#        [[329, 372]],
#
#        [[328, 372]],
#
#        [[326, 370]],
#
#        [[326, 368]],
#
#        [[327, 367]],
#
#        [[327, 365]],
#
#        [[328, 364]],
#
#        [[328, 363]],
#
#        [[330, 361]]], dtype=int32), array([[[321, 360]],
#
#        [[321, 362]],
#
#        [[320, 363]],
#
#        [[322, 363]],
#
#        [[323, 362]],
#
#        [[323, 361]],
#
#        [[322, 360]]], dtype=int32), array([[[276, 359]],
#
#        [[277, 358]],
#
#        [[278, 359]],
#
#        [[277, 360]]], dtype=int32), array([[[202, 359]],
#
#        [[203, 358]],
#
#        [[204, 359]],
#
#        [[203, 360]]], dtype=int32), array([[[194, 359]],
#
#        [[195, 358]],
#
#        [[196, 359]],
#
#        [[195, 360]]], dtype=int32), array([[[358, 358]],
#
#        [[359, 357]],
#
#        [[360, 358]],
#
#        [[360, 359]],
#
#        [[359, 360]],
#
#        [[358, 359]]], dtype=int32), array([[[349, 358]],
#
#        [[350, 357]],
#
#        [[351, 358]],
#
#        [[350, 359]]], dtype=int32), array([[[186, 358]],
#
#        [[187, 357]],
#
#        [[188, 358]],
#
#        [[188, 359]],
#
#        [[187, 360]],
#
#        [[186, 359]]], dtype=int32), array([[[367, 356]],
#
#        [[369, 356]],
#
#        [[370, 357]],
#
#        [[370, 359]],
#
#        [[369, 360]],
#
#        [[366, 360]],
#
#        [[365, 359]],
#
#        [[365, 358]]], dtype=int32), array([[[321, 356]],
#
#        [[322, 357]],
#
#        [[324, 357]],
#
#        [[325, 358]],
#
#        [[325, 359]],
#
#        [[326, 360]],
#
#        [[326, 362]],
#
#        [[325, 363]],
#
#        [[325, 364]],
#
#        [[321, 368]],
#
#        [[320, 368]],
#
#        [[318, 366]],
#
#        [[318, 365]],
#
#        [[317, 364]],
#
#        [[318, 363]],
#
#        [[317, 362]],
#
#        [[318, 361]],
#
#        [[317, 360]]], dtype=int32), array([[[298, 357]],
#
#        [[299, 356]],
#
#        [[300, 356]],
#
#        [[301, 357]],
#
#        [[301, 361]],
#
#        [[300, 362]],
#
#        [[300, 367]],
#
#        [[299, 368]],
#
#        [[297, 368]],
#
#        [[296, 367]],
#
#        [[296, 364]],
#
#        [[297, 363]],
#
#        [[297, 360]],
#
#        [[298, 359]]], dtype=int32), array([[[199, 357]],
#
#        [[200, 356]],
#
#        [[201, 357]],
#
#        [[201, 358]],
#
#        [[200, 359]],
#
#        [[199, 358]]], dtype=int32), array([[[180, 357]],
#
#        [[181, 356]],
#
#        [[182, 356]],
#
#        [[183, 357]],
#
#        [[182, 358]],
#
#        [[181, 358]]], dtype=int32), array([[[347, 356]],
#
#        [[348, 355]],
#
#        [[351, 355]],
#
#        [[352, 356]],
#
#        [[351, 357]],
#
#        [[348, 357]]], dtype=int32), array([[[339, 355]],
#
#        [[340, 356]],
#
#        [[343, 356]],
#
#        [[344, 357]],
#
#        [[346, 357]],
#
#        [[348, 359]],
#
#        [[347, 360]],
#
#        [[342, 360]],
#
#        [[341, 359]],
#
#        [[338, 359]],
#
#        [[337, 358]],
#
#        [[337, 357]]], dtype=int32), array([[[201, 356]],
#
#        [[202, 355]],
#
#        [[203, 356]],
#
#        [[202, 357]]], dtype=int32), array([[[179, 356]],
#
#        [[180, 355]],
#
#        [[181, 356]],
#
#        [[180, 357]]], dtype=int32), array([[[343, 355]],
#
#        [[344, 354]],
#
#        [[345, 355]],
#
#        [[344, 356]]], dtype=int32), array([[[335, 355]],
#
#        [[336, 354]],
#
#        [[337, 355]],
#
#        [[336, 356]]], dtype=int32), array([[[178, 355]],
#
#        [[179, 354]],
#
#        [[180, 355]],
#
#        [[179, 356]]], dtype=int32), array([[[347, 354]],
#
#        [[348, 353]],
#
#        [[351, 353]],
#
#        [[352, 354]],
#
#        [[351, 355]],
#
#        [[348, 355]]], dtype=int32), array([[[202, 352]],
#
#        [[203, 351]],
#
#        [[204, 352]],
#
#        [[203, 353]]], dtype=int32), array([[[168, 352]],
#
#        [[169, 351]],
#
#        [[170, 352]],
#
#        [[170, 353]],
#
#        [[169, 354]],
#
#        [[168, 353]]], dtype=int32), array([[[322, 351]],
#
#        [[323, 350]],
#
#        [[324, 351]],
#
#        [[323, 352]]], dtype=int32), array([[[227, 351]],
#
#        [[228, 350]],
#
#        [[229, 351]],
#
#        [[228, 352]]], dtype=int32), array([[[172, 351]],
#
#        [[173, 350]],
#
#        [[174, 351]],
#
#        [[173, 352]]], dtype=int32), array([[[ 52, 351]],
#
#        [[ 53, 350]],
#
#        [[ 54, 351]],
#
#        [[ 53, 352]]], dtype=int32), array([[[579, 350]],
#
#        [[580, 349]],
#
#        [[583, 349]],
#
#        [[584, 350]],
#
#        [[583, 351]],
#
#        [[580, 351]]], dtype=int32), array([[[253, 350]],
#
#        [[254, 349]],
#
#        [[256, 349]],
#
#        [[257, 350]],
#
#        [[259, 350]],
#
#        [[260, 351]],
#
#        [[259, 352]],
#
#        [[254, 352]],
#
#        [[253, 351]]], dtype=int32), array([[[298, 349]],
#
#        [[299, 348]],
#
#        [[301, 348]],
#
#        [[302, 349]],
#
#        [[302, 351]],
#
#        [[301, 352]],
#
#        [[299, 352]],
#
#        [[298, 351]]], dtype=int32), array([[[252, 349]],
#
#        [[253, 348]],
#
#        [[254, 349]],
#
#        [[253, 350]]], dtype=int32), array([[[596, 348]],
#
#        [[597, 347]],
#
#        [[598, 348]],
#
#        [[597, 349]]], dtype=int32), array([[[315, 347]],
#
#        [[316, 346]],
#
#        [[318, 346]],
#
#        [[319, 347]],
#
#        [[319, 352]],
#
#        [[318, 353]],
#
#        [[318, 354]],
#
#        [[317, 355]],
#
#        [[317, 357]],
#
#        [[316, 358]],
#
#        [[316, 362]],
#
#        [[314, 364]],
#
#        [[313, 364]],
#
#        [[313, 365]],
#
#        [[311, 367]],
#
#        [[311, 368]],
#
#        [[309, 370]],
#
#        [[306, 370]],
#
#        [[304, 368]],
#
#        [[304, 367]],
#
#        [[305, 366]],
#
#        [[305, 365]],
#
#        [[306, 364]],
#
#        [[306, 363]],
#
#        [[309, 360]],
#
#        [[313, 360]],
#
#        [[313, 357]],
#
#        [[314, 356]],
#
#        [[314, 352]],
#
#        [[315, 351]],
#
#        [[315, 350]],
#
#        [[314, 349]],
#
#        [[315, 348]]], dtype=int32), array([[[236, 347]],
#
#        [[237, 346]],
#
#        [[242, 346]],
#
#        [[243, 347]],
#
#        [[248, 347]],
#
#        [[249, 348]],
#
#        [[250, 348]],
#
#        [[251, 349]],
#
#        [[250, 350]],
#
#        [[243, 350]],
#
#        [[242, 349]],
#
#        [[240, 349]],
#
#        [[239, 348]],
#
#        [[238, 349]],
#
#        [[237, 349]],
#
#        [[236, 348]]], dtype=int32), array([[[ 48, 347]],
#
#        [[ 49, 346]],
#
#        [[ 50, 347]],
#
#        [[ 50, 348]],
#
#        [[ 49, 349]],
#
#        [[ 48, 348]]], dtype=int32), array([[[209, 345]],
#
#        [[210, 344]],
#
#        [[211, 344]],
#
#        [[212, 345]],
#
#        [[211, 346]],
#
#        [[210, 346]]], dtype=int32), array([[[656, 344]],
#
#        [[657, 343]],
#
#        [[659, 343]],
#
#        [[660, 344]],
#
#        [[659, 345]],
#
#        [[657, 345]]], dtype=int32), array([[[370, 344]],
#
#        [[371, 343]],
#
#        [[372, 344]],
#
#        [[371, 345]]], dtype=int32), array([[[250, 344]],
#
#        [[251, 343]],
#
#        [[252, 344]],
#
#        [[251, 345]]], dtype=int32), array([[[490, 343]],
#
#        [[491, 342]],
#
#        [[492, 342]],
#
#        [[493, 343]],
#
#        [[492, 344]],
#
#        [[491, 344]]], dtype=int32), array([[[201, 343]],
#
#        [[202, 342]],
#
#        [[205, 342]],
#
#        [[207, 344]],
#
#        [[207, 346]],
#
#        [[208, 347]],
#
#        [[207, 348]],
#
#        [[207, 349]],
#
#        [[208, 350]],
#
#        [[206, 352]],
#
#        [[204, 352]],
#
#        [[203, 351]],
#
#        [[203, 346]],
#
#        [[202, 346]],
#
#        [[201, 347]],
#
#        [[200, 347]],
#
#        [[200, 348]],
#
#        [[199, 349]],
#
#        [[199, 351]],
#
#        [[196, 354]],
#
#        [[195, 354]],
#
#        [[194, 353]],
#
#        [[194, 350]],
#
#        [[195, 349]],
#
#        [[195, 348]],
#
#        [[200, 343]]], dtype=int32), array([[[486, 342]],
#
#        [[487, 341]],
#
#        [[488, 342]],
#
#        [[487, 343]]], dtype=int32), array([[[267, 341]],
#
#        [[268, 341]],
#
#        [[272, 345]],
#
#        [[273, 345]],
#
#        [[277, 349]],
#
#        [[277, 350]],
#
#        [[278, 350]],
#
#        [[279, 351]],
#
#        [[279, 354]],
#
#        [[278, 355]],
#
#        [[277, 355]],
#
#        [[276, 356]],
#
#        [[275, 355]],
#
#        [[273, 355]],
#
#        [[272, 354]],
#
#        [[274, 352]],
#
#        [[275, 352]],
#
#        [[274, 351]],
#
#        [[274, 350]],
#
#        [[273, 349]],
#
#        [[272, 349]],
#
#        [[272, 350]],
#
#        [[273, 351]],
#
#        [[272, 352]],
#
#        [[271, 352]],
#
#        [[272, 353]],
#
#        [[272, 354]],
#
#        [[271, 355]],
#
#        [[269, 355]],
#
#        [[267, 353]],
#
#        [[263, 353]],
#
#        [[262, 352]],
#
#        [[263, 351]],
#
#        [[269, 351]],
#
#        [[269, 348]],
#
#        [[266, 345]],
#
#        [[266, 344]],
#
#        [[265, 343]]], dtype=int32), array([[[363, 340]],
#
#        [[365, 340]],
#
#        [[367, 342]],
#
#        [[367, 347]],
#
#        [[369, 349]],
#
#        [[367, 351]],
#
#        [[367, 353]],
#
#        [[365, 355]],
#
#        [[364, 355]],
#
#        [[363, 354]],
#
#        [[363, 352]],
#
#        [[364, 351]],
#
#        [[364, 349]],
#
#        [[365, 348]],
#
#        [[365, 346]],
#
#        [[364, 345]],
#
#        [[364, 344]],
#
#        [[363, 344]],
#
#        [[363, 347]],
#
#        [[362, 348]],
#
#        [[362, 351]],
#
#        [[361, 352]],
#
#        [[361, 356]],
#
#        [[360, 357]],
#
#        [[359, 356]],
#
#        [[359, 353]],
#
#        [[358, 352]],
#
#        [[358, 351]],
#
#        [[359, 350]],
#
#        [[359, 346]],
#
#        [[360, 345]],
#
#        [[360, 344]],
#
#        [[361, 343]],
#
#        [[361, 342]]], dtype=int32), array([[[235, 341]],
#
#        [[234, 342]],
#
#        [[233, 342]],
#
#        [[232, 343]],
#
#        [[230, 343]],
#
#        [[232, 343]],
#
#        [[233, 342]],
#
#        [[235, 342]],
#
#        [[236, 341]],
#
#        [[238, 341]]], dtype=int32), array([[[158, 341]],
#
#        [[157, 342]],
#
#        [[157, 343]],
#
#        [[156, 344]],
#
#        [[156, 346]],
#
#        [[155, 347]],
#
#        [[155, 348]],
#
#        [[156, 349]],
#
#        [[159, 349]],
#
#        [[162, 346]],
#
#        [[162, 343]],
#
#        [[161, 342]],
#
#        [[160, 342]],
#
#        [[159, 341]]], dtype=int32), array([[[345, 339]],
#
#        [[346, 340]],
#
#        [[346, 341]],
#
#        [[347, 342]],
#
#        [[347, 343]],
#
#        [[346, 344]],
#
#        [[346, 353]],
#
#        [[345, 354]],
#
#        [[344, 354]],
#
#        [[343, 353]],
#
#        [[343, 344]],
#
#        [[342, 343]],
#
#        [[342, 342]]], dtype=int32), array([[[196, 339]],
#
#        [[197, 338]],
#
#        [[198, 339]],
#
#        [[197, 340]]], dtype=int32), array([[[175, 339]],
#
#        [[176, 338]],
#
#        [[181, 338]],
#
#        [[182, 339]],
#
#        [[183, 339]],
#
#        [[184, 340]],
#
#        [[184, 342]],
#
#        [[182, 344]],
#
#        [[181, 344]],
#
#        [[181, 345]],
#
#        [[180, 346]],
#
#        [[180, 347]],
#
#        [[179, 348]],
#
#        [[179, 350]],
#
#        [[177, 352]],
#
#        [[177, 356]],
#
#        [[175, 358]],
#
#        [[175, 360]],
#
#        [[174, 361]],
#
#        [[174, 362]],
#
#        [[173, 363]],
#
#        [[173, 364]],
#
#        [[172, 365]],
#
#        [[172, 366]],
#
#        [[170, 368]],
#
#        [[167, 368]],
#
#        [[164, 365]],
#
#        [[165, 364]],
#
#        [[165, 362]],
#
#        [[166, 361]],
#
#        [[166, 360]],
#
#        [[167, 359]],
#
#        [[168, 360]],
#
#        [[168, 363]],
#
#        [[169, 364]],
#
#        [[170, 364]],
#
#        [[170, 363]],
#
#        [[171, 362]],
#
#        [[171, 361]],
#
#        [[172, 360]],
#
#        [[172, 358]],
#
#        [[173, 357]],
#
#        [[173, 355]],
#
#        [[174, 354]],
#
#        [[174, 353]],
#
#        [[175, 352]],
#
#        [[175, 350]],
#
#        [[176, 349]],
#
#        [[176, 348]],
#
#        [[177, 347]],
#
#        [[174, 347]],
#
#        [[173, 346]],
#
#        [[172, 346]],
#
#        [[171, 345]],
#
#        [[171, 341]],
#
#        [[172, 340]],
#
#        [[173, 340]],
#
#        [[174, 339]],
#
#        [[176, 341]],
#
#        [[174, 343]],
#
#        [[175, 344]],
#
#        [[178, 344]],
#
#        [[179, 343]],
#
#        [[179, 341]],
#
#        [[176, 341]],
#
#        [[175, 340]]], dtype=int32), array([[[157, 339]],
#
#        [[158, 338]],
#
#        [[161, 338]],
#
#        [[163, 340]],
#
#        [[164, 340]],
#
#        [[166, 342]],
#
#        [[166, 345]],
#
#        [[165, 346]],
#
#        [[165, 348]],
#
#        [[164, 349]],
#
#        [[163, 349]],
#
#        [[163, 350]],
#
#        [[162, 351]],
#
#        [[161, 351]],
#
#        [[160, 352]],
#
#        [[154, 352]],
#
#        [[153, 351]],
#
#        [[153, 350]],
#
#        [[152, 349]],
#
#        [[152, 347]],
#
#        [[153, 346]],
#
#        [[153, 345]],
#
#        [[152, 344]],
#
#        [[154, 342]],
#
#        [[154, 340]],
#
#        [[155, 339]]], dtype=int32), array([[[565, 338]],
#
#        [[566, 337]],
#
#        [[567, 337]],
#
#        [[568, 338]],
#
#        [[567, 339]],
#
#        [[566, 339]]], dtype=int32), array([[[238, 338]],
#
#        [[239, 337]],
#
#        [[241, 337]],
#
#        [[242, 338]],
#
#        [[243, 338]],
#
#        [[244, 339]],
#
#        [[244, 341]],
#
#        [[243, 342]],
#
#        [[240, 342]],
#
#        [[239, 343]],
#
#        [[237, 343]],
#
#        [[236, 344]],
#
#        [[234, 344]],
#
#        [[233, 345]],
#
#        [[231, 345]],
#
#        [[232, 346]],
#
#        [[235, 346]],
#
#        [[236, 347]],
#
#        [[235, 348]],
#
#        [[231, 348]],
#
#        [[233, 350]],
#
#        [[235, 350]],
#
#        [[236, 351]],
#
#        [[239, 351]],
#
#        [[241, 353]],
#
#        [[241, 354]],
#
#        [[240, 355]],
#
#        [[237, 355]],
#
#        [[236, 354]],
#
#        [[234, 354]],
#
#        [[233, 353]],
#
#        [[232, 353]],
#
#        [[231, 352]],
#
#        [[231, 351]],
#
#        [[230, 351]],
#
#        [[229, 350]],
#
#        [[229, 347]],
#
#        [[229, 348]],
#
#        [[228, 349]],
#
#        [[227, 348]],
#
#        [[227, 347]],
#
#        [[223, 347]],
#
#        [[221, 345]],
#
#        [[222, 344]],
#
#        [[222, 343]],
#
#        [[223, 342]],
#
#        [[224, 343]],
#
#        [[226, 343]],
#
#        [[226, 342]],
#
#        [[227, 341]],
#
#        [[228, 341]],
#
#        [[229, 340]],
#
#        [[233, 340]],
#
#        [[233, 339]],
#
#        [[234, 338]]], dtype=int32), array([[[190, 337]],
#
#        [[191, 337]],
#
#        [[192, 338]],
#
#        [[192, 342]],
#
#        [[190, 344]],
#
#        [[190, 346]],
#
#        [[189, 347]],
#
#        [[189, 349]],
#
#        [[188, 350]],
#
#        [[188, 351]],
#
#        [[185, 354]],
#
#        [[183, 352]],
#
#        [[183, 351]],
#
#        [[184, 350]],
#
#        [[184, 349]],
#
#        [[185, 348]],
#
#        [[185, 347]],
#
#        [[187, 345]],
#
#        [[187, 341]],
#
#        [[188, 340]],
#
#        [[188, 339]]], dtype=int32), array([[[551, 337]],
#
#        [[552, 336]],
#
#        [[553, 336]],
#
#        [[554, 337]],
#
#        [[553, 338]],
#
#        [[552, 338]]], dtype=int32), array([[[341, 336]],
#
#        [[342, 335]],
#
#        [[343, 336]],
#
#        [[342, 337]]], dtype=int32), array([[[222, 336]],
#
#        [[223, 335]],
#
#        [[224, 335]],
#
#        [[225, 336]],
#
#        [[224, 337]],
#
#        [[223, 337]]], dtype=int32), array([[[218, 336]],
#
#        [[219, 335]],
#
#        [[220, 335]],
#
#        [[221, 336]],
#
#        [[220, 337]],
#
#        [[219, 337]]], dtype=int32), array([[[202, 336]],
#
#        [[203, 335]],
#
#        [[204, 336]],
#
#        [[203, 337]]], dtype=int32), array([[[184, 336]],
#
#        [[185, 335]],
#
#        [[186, 336]],
#
#        [[185, 337]]], dtype=int32), array([[[ 96, 336]],
#
#        [[ 97, 335]],
#
#        [[ 98, 336]],
#
#        [[ 97, 337]]], dtype=int32), array([[[583, 335]],
#
#        [[584, 334]],
#
#        [[585, 334]],
#
#        [[586, 335]],
#
#        [[585, 336]],
#
#        [[584, 336]]], dtype=int32), array([[[552, 335]],
#
#        [[553, 334]],
#
#        [[554, 334]],
#
#        [[555, 335]],
#
#        [[554, 336]],
#
#        [[553, 336]]], dtype=int32), array([[[542, 335]],
#
#        [[543, 334]],
#
#        [[544, 335]],
#
#        [[543, 336]]], dtype=int32), array([[[586, 334]],
#
#        [[587, 333]],
#
#        [[588, 333]],
#
#        [[589, 334]],
#
#        [[588, 335]],
#
#        [[587, 335]]], dtype=int32), array([[[550, 334]],
#
#        [[551, 333]],
#
#        [[552, 334]],
#
#        [[551, 335]]], dtype=int32), array([[[576, 332]],
#
#        [[577, 331]],
#
#        [[578, 332]],
#
#        [[577, 333]]], dtype=int32), array([[[601, 330]],
#
#        [[603, 330]],
#
#        [[604, 331]],
#
#        [[603, 332]],
#
#        [[603, 333]],
#
#        [[604, 334]],
#
#        [[604, 335]],
#
#        [[603, 336]],
#
#        [[599, 332]]], dtype=int32), array([[[602, 328]],
#
#        [[603, 327]],
#
#        [[604, 327]],
#
#        [[605, 328]],
#
#        [[604, 329]],
#
#        [[603, 329]]], dtype=int32), array([[[519, 327]],
#
#        [[520, 326]],
#
#        [[521, 326]],
#
#        [[522, 327]],
#
#        [[521, 328]],
#
#        [[520, 328]]], dtype=int32), array([[[162, 327]],
#
#        [[163, 326]],
#
#        [[164, 327]],
#
#        [[163, 328]]], dtype=int32), array([[[597, 324]],
#
#        [[596, 325]],
#
#        [[597, 325]]], dtype=int32), array([[[500, 323]],
#
#        [[501, 322]],
#
#        [[502, 323]],
#
#        [[501, 324]]], dtype=int32), array([[[729, 320]],
#
#        [[730, 319]],
#
#        [[731, 320]],
#
#        [[730, 321]]], dtype=int32), array([[[499, 320]],
#
#        [[500, 319]],
#
#        [[501, 320]],
#
#        [[500, 321]]], dtype=int32), array([[[162, 320]],
#
#        [[163, 319]],
#
#        [[164, 320]],
#
#        [[163, 321]]], dtype=int32), array([[[654, 319]],
#
#        [[655, 318]],
#
#        [[656, 319]],
#
#        [[655, 320]]], dtype=int32), array([[[583, 319]],
#
#        [[584, 318]],
#
#        [[585, 319]],
#
#        [[585, 321]],
#
#        [[584, 322]],
#
#        [[584, 323]],
#
#        [[582, 325]],
#
#        [[582, 327]],
#
#        [[583, 328]],
#
#        [[584, 327]],
#
#        [[585, 327]],
#
#        [[585, 325]],
#
#        [[588, 322]],
#
#        [[589, 323]],
#
#        [[589, 326]],
#
#        [[588, 327]],
#
#        [[591, 327]],
#
#        [[591, 326]],
#
#        [[595, 322]],
#
#        [[596, 322]],
#
#        [[597, 321]],
#
#        [[600, 321]],
#
#        [[601, 322]],
#
#        [[601, 325]],
#
#        [[600, 326]],
#
#        [[599, 326]],
#
#        [[596, 329]],
#
#        [[599, 329]],
#
#        [[600, 330]],
#
#        [[598, 332]],
#
#        [[594, 332]],
#
#        [[591, 329]],
#
#        [[589, 329]],
#
#        [[588, 330]],
#
#        [[585, 330]],
#
#        [[584, 331]],
#
#        [[581, 331]],
#
#        [[580, 330]],
#
#        [[580, 329]],
#
#        [[579, 328]],
#
#        [[579, 327]],
#
#        [[580, 326]],
#
#        [[580, 322]],
#
#        [[581, 321]],
#
#        [[581, 320]],
#
#        [[582, 319]]], dtype=int32), array([[[317, 319]],
#
#        [[318, 318]],
#
#        [[319, 319]],
#
#        [[318, 320]]], dtype=int32), array([[[304, 319]],
#
#        [[305, 318]],
#
#        [[306, 319]],
#
#        [[305, 320]]], dtype=int32), array([[[299, 319]],
#
#        [[300, 318]],
#
#        [[301, 319]],
#
#        [[300, 320]]], dtype=int32), array([[[287, 319]],
#
#        [[288, 318]],
#
#        [[289, 319]],
#
#        [[288, 320]]], dtype=int32), array([[[280, 319]],
#
#        [[281, 318]],
#
#        [[282, 318]],
#
#        [[283, 319]],
#
#        [[282, 320]],
#
#        [[281, 320]]], dtype=int32), array([[[710, 318]],
#
#        [[711, 317]],
#
#        [[712, 318]],
#
#        [[711, 319]]], dtype=int32), array([[[706, 318]],
#
#        [[707, 317]],
#
#        [[708, 318]],
#
#        [[707, 319]]], dtype=int32), array([[[672, 318]],
#
#        [[673, 317]],
#
#        [[674, 317]],
#
#        [[675, 318]],
#
#        [[674, 319]],
#
#        [[673, 319]]], dtype=int32), array([[[540, 318]],
#
#        [[541, 317]],
#
#        [[542, 318]],
#
#        [[541, 319]]], dtype=int32), array([[[326, 318]],
#
#        [[327, 317]],
#
#        [[328, 318]],
#
#        [[327, 319]]], dtype=int32), array([[[160, 318]],
#
#        [[161, 317]],
#
#        [[163, 319]],
#
#        [[162, 320]],
#
#        [[162, 322]],
#
#        [[161, 323]],
#
#        [[160, 323]],
#
#        [[160, 325]],
#
#        [[158, 327]],
#
#        [[158, 329]],
#
#        [[157, 330]],
#
#        [[157, 331]],
#
#        [[156, 332]],
#
#        [[156, 333]],
#
#        [[155, 334]],
#
#        [[155, 335]],
#
#        [[154, 336]],
#
#        [[154, 337]],
#
#        [[153, 338]],
#
#        [[153, 339]],
#
#        [[152, 340]],
#
#        [[152, 342]],
#
#        [[151, 343]],
#
#        [[150, 343]],
#
#        [[151, 344]],
#
#        [[149, 346]],
#
#        [[149, 348]],
#
#        [[147, 350]],
#
#        [[147, 351]],
#
#        [[145, 353]],
#
#        [[145, 354]],
#
#        [[143, 356]],
#
#        [[143, 357]],
#
#        [[142, 358]],
#
#        [[140, 358]],
#
#        [[139, 357]],
#
#        [[139, 355]],
#
#        [[143, 351]],
#
#        [[144, 351]],
#
#        [[143, 350]],
#
#        [[145, 348]],
#
#        [[145, 347]],
#
#        [[146, 346]],
#
#        [[147, 347]],
#
#        [[147, 345]],
#
#        [[148, 344]],
#
#        [[148, 341]],
#
#        [[150, 339]],
#
#        [[150, 338]],
#
#        [[152, 336]],
#
#        [[152, 333]],
#
#        [[153, 332]],
#
#        [[153, 331]],
#
#        [[154, 330]],
#
#        [[154, 328]],
#
#        [[155, 327]],
#
#        [[155, 325]],
#
#        [[157, 323]],
#
#        [[157, 321]],
#
#        [[158, 320]],
#
#        [[158, 319]],
#
#        [[159, 318]]], dtype=int32), array([[[656, 317]],
#
#        [[657, 316]],
#
#        [[658, 316]],
#
#        [[659, 317]],
#
#        [[658, 318]],
#
#        [[657, 318]]], dtype=int32), array([[[277, 317]],
#
#        [[278, 316]],
#
#        [[279, 317]],
#
#        [[278, 318]]], dtype=int32), array([[[541, 315]],
#
#        [[542, 314]],
#
#        [[546, 314]],
#
#        [[547, 315]],
#
#        [[549, 315]],
#
#        [[550, 316]],
#
#        [[552, 316]],
#
#        [[554, 318]],
#
#        [[557, 318]],
#
#        [[558, 319]],
#
#        [[558, 322]],
#
#        [[557, 323]],
#
#        [[556, 323]],
#
#        [[555, 324]],
#
#        [[555, 327]],
#
#        [[556, 328]],
#
#        [[559, 328]],
#
#        [[560, 327]],
#
#        [[562, 327]],
#
#        [[564, 325]],
#
#        [[566, 325]],
#
#        [[567, 326]],
#
#        [[567, 327]],
#
#        [[566, 328]],
#
#        [[566, 329]],
#
#        [[564, 331]],
#
#        [[563, 331]],
#
#        [[562, 330]],
#
#        [[560, 330]],
#
#        [[559, 331]],
#
#        [[554, 331]],
#
#        [[551, 328]],
#
#        [[551, 325]],
#
#        [[553, 323]],
#
#        [[553, 322]],
#
#        [[554, 321]],
#
#        [[554, 320]],
#
#        [[551, 320]],
#
#        [[550, 319]],
#
#        [[548, 319]],
#
#        [[547, 318]],
#
#        [[543, 318]],
#
#        [[541, 316]]], dtype=int32), array([[[528, 315]],
#
#        [[529, 314]],
#
#        [[533, 314]],
#
#        [[534, 315]],
#
#        [[534, 317]],
#
#        [[532, 319]],
#
#        [[528, 319]],
#
#        [[527, 320]],
#
#        [[529, 322]],
#
#        [[533, 322]],
#
#        [[534, 321]],
#
#        [[536, 321]],
#
#        [[537, 320]],
#
#        [[539, 320]],
#
#        [[540, 321]],
#
#        [[540, 324]],
#
#        [[539, 325]],
#
#        [[540, 325]],
#
#        [[541, 324]],
#
#        [[542, 324]],
#
#        [[544, 322]],
#
#        [[547, 322]],
#
#        [[548, 323]],
#
#        [[547, 324]],
#
#        [[547, 328]],
#
#        [[545, 330]],
#
#        [[544, 329]],
#
#        [[544, 328]],
#
#        [[543, 327]],
#
#        [[542, 327]],
#
#        [[541, 328]],
#
#        [[537, 328]],
#
#        [[536, 327]],
#
#        [[536, 324]],
#
#        [[533, 324]],
#
#        [[532, 325]],
#
#        [[528, 325]],
#
#        [[527, 324]],
#
#        [[526, 324]],
#
#        [[525, 323]],
#
#        [[525, 322]],
#
#        [[524, 321]],
#
#        [[524, 319]],
#
#        [[525, 318]],
#
#        [[525, 317]],
#
#        [[527, 315]]], dtype=int32), array([[[161, 314]],
#
#        [[162, 313]],
#
#        [[163, 314]],
#
#        [[162, 315]]], dtype=int32), array([[[680, 313]],
#
#        [[681, 312]],
#
#        [[683, 312]],
#
#        [[684, 313]],
#
#        [[683, 314]],
#
#        [[681, 314]]], dtype=int32), array([[[555, 313]],
#
#        [[556, 312]],
#
#        [[557, 313]],
#
#        [[556, 314]]], dtype=int32), array([[[578, 312]],
#
#        [[576, 314]],
#
#        [[575, 314]],
#
#        [[574, 315]],
#
#        [[574, 316]],
#
#        [[575, 316]],
#
#        [[577, 314]],
#
#        [[578, 314]],
#
#        [[580, 312]]], dtype=int32), array([[[566, 312]],
#
#        [[567, 311]],
#
#        [[568, 312]],
#
#        [[567, 313]]], dtype=int32), array([[[560, 312]],
#
#        [[561, 311]],
#
#        [[562, 311]],
#
#        [[563, 312]],
#
#        [[562, 313]],
#
#        [[561, 313]]], dtype=int32), array([[[554, 312]],
#
#        [[555, 311]],
#
#        [[556, 312]],
#
#        [[555, 313]]], dtype=int32), array([[[511, 312]],
#
#        [[512, 311]],
#
#        [[513, 311]],
#
#        [[514, 312]],
#
#        [[513, 313]],
#
#        [[512, 313]]], dtype=int32), array([[[157, 312]],
#
#        [[158, 311]],
#
#        [[159, 311]],
#
#        [[160, 312]],
#
#        [[159, 313]],
#
#        [[158, 313]]], dtype=int32), array([[[ 66, 312]],
#
#        [[ 67, 311]],
#
#        [[ 68, 312]],
#
#        [[ 67, 313]]], dtype=int32), array([[[617, 311]],
#
#        [[618, 310]],
#
#        [[619, 311]],
#
#        [[618, 312]]], dtype=int32), array([[[597, 311]],
#
#        [[598, 310]],
#
#        [[599, 310]],
#
#        [[600, 311]],
#
#        [[599, 312]],
#
#        [[598, 312]]], dtype=int32), array([[[567, 311]],
#
#        [[568, 310]],
#
#        [[569, 311]],
#
#        [[568, 312]]], dtype=int32), array([[[503, 311]],
#
#        [[504, 310]],
#
#        [[505, 310]],
#
#        [[506, 311]],
#
#        [[505, 312]],
#
#        [[504, 312]]], dtype=int32), array([[[500, 310]],
#
#        [[501, 309]],
#
#        [[502, 310]],
#
#        [[502, 311]],
#
#        [[501, 312]],
#
#        [[500, 311]]], dtype=int32), array([[[ 71, 310]],
#
#        [[ 72, 309]],
#
#        [[ 73, 310]],
#
#        [[ 72, 311]]], dtype=int32), array([[[578, 308]],
#
#        [[582, 308]],
#
#        [[583, 309]],
#
#        [[583, 310]],
#
#        [[584, 311]],
#
#        [[583, 312]],
#
#        [[583, 313]],
#
#        [[582, 314]],
#
#        [[581, 314]],
#
#        [[581, 315]],
#
#        [[579, 317]],
#
#        [[578, 317]],
#
#        [[575, 320]],
#
#        [[572, 320]],
#
#        [[571, 321]],
#
#        [[571, 325]],
#
#        [[572, 326]],
#
#        [[572, 327]],
#
#        [[573, 328]],
#
#        [[574, 328]],
#
#        [[576, 326]],
#
#        [[576, 320]],
#
#        [[577, 319]],
#
#        [[578, 320]],
#
#        [[578, 321]],
#
#        [[579, 322]],
#
#        [[579, 327]],
#
#        [[578, 328]],
#
#        [[578, 329]],
#
#        [[577, 330]],
#
#        [[576, 330]],
#
#        [[575, 331]],
#
#        [[571, 331]],
#
#        [[569, 329]],
#
#        [[569, 327]],
#
#        [[568, 326]],
#
#        [[568, 322]],
#
#        [[564, 322]],
#
#        [[563, 323]],
#
#        [[562, 323]],
#
#        [[561, 322]],
#
#        [[561, 320]],
#
#        [[562, 319]],
#
#        [[566, 319]],
#
#        [[567, 318]],
#
#        [[570, 318]],
#
#        [[571, 317]],
#
#        [[571, 316]],
#
#        [[572, 315]],
#
#        [[572, 314]]], dtype=int32), array([[[ 79, 308]],
#
#        [[ 80, 307]],
#
#        [[ 81, 308]],
#
#        [[ 80, 309]]], dtype=int32), array([[[ 67, 308]],
#
#        [[ 68, 307]],
#
#        [[ 69, 307]],
#
#        [[ 70, 308]],
#
#        [[ 69, 309]],
#
#        [[ 68, 309]]], dtype=int32), array([[[502, 307]],
#
#        [[503, 306]],
#
#        [[504, 307]],
#
#        [[504, 308]],
#
#        [[503, 309]],
#
#        [[502, 308]]], dtype=int32), array([[[329, 307]],
#
#        [[330, 306]],
#
#        [[331, 306]],
#
#        [[332, 307]],
#
#        [[332, 308]],
#
#        [[333, 307]],
#
#        [[334, 307]],
#
#        [[335, 306]],
#
#        [[336, 306]],
#
#        [[338, 308]],
#
#        [[338, 309]],
#
#        [[337, 310]],
#
#        [[335, 310]],
#
#        [[335, 311]],
#
#        [[334, 312]],
#
#        [[334, 314]],
#
#        [[331, 317]],
#
#        [[329, 317]],
#
#        [[328, 316]],
#
#        [[328, 313]],
#
#        [[329, 312]]], dtype=int32), array([[[290, 307]],
#
#        [[290, 308]],
#
#        [[293, 308]],
#
#        [[292, 307]]], dtype=int32), array([[[647, 306]],
#
#        [[648, 305]],
#
#        [[649, 306]],
#
#        [[648, 307]]], dtype=int32), array([[[655, 304]],
#
#        [[656, 303]],
#
#        [[657, 304]],
#
# ...
#
#        [[559,  48]],
#
#        [[565,  54]],
#
#        [[565,  55]],
#
#        [[566,  55]],
#
#        [[576,  65]],
#
#        [[575,  66]],
#
#        [[579,  66]],
#
#        [[580,  65]],
#
#        [[577,  62]],
#
#        [[577,  60]],
#
#        [[576,  59]],
#
#        [[576,  56]],
#
#        [[575,  55]],
#
#        [[575,  52]],
#
#        [[574,  51]],
#
#        [[574,  38]],
#
#        [[575,  37]],
#
#        [[575,  35]],
#
#        [[576,  34]],
#
#        [[576,  33]],
#
#        [[577,  32]],
#
#        [[577,  30]],
#
#        [[578,  29]],
#
#        [[579,  29]],
#
#        [[579,  27]],
#
#        [[580,  26]],
#
#        [[581,  26]],
#
#        [[581,  25]],
#
#        [[582,  24]],
#
#        [[583,  24]],
#
#        [[583,  23]],
#
#        [[560,  23]],
#
#        [[559,  22]]], dtype=int32), array([[[223,  22]],
#
#        [[224,  21]],
#
#        [[225,  22]],
#
#        [[226,  21]],
#
#        [[239,  21]],
#
#        [[240,  22]],
#
#        [[240,  23]],
#
#        [[241,  24]],
#
#        [[241,  26]],
#
#        [[239,  28]],
#
#        [[237,  26]],
#
#        [[237,  24]],
#
#        [[222,  24]],
#
#        [[221,  25]],
#
#        [[220,  25]],
#
#        [[219,  26]],
#
#        [[216,  26]],
#
#        [[214,  28]],
#
#        [[211,  28]],
#
#        [[209,  30]],
#
#        [[208,  30]],
#
#        [[206,  32]],
#
#        [[206,  34]],
#
#        [[208,  36]],
#
#        [[210,  36]],
#
#        [[212,  38]],
#
#        [[211,  39]],
#
#        [[208,  39]],
#
#        [[207,  38]],
#
#        [[206,  38]],
#
#        [[203,  35]],
#
#        [[203,  34]],
#
#        [[202,  33]],
#
#        [[202,  31]],
#
#        [[205,  28]],
#
#        [[206,  28]],
#
#        [[207,  27]],
#
#        [[208,  27]],
#
#        [[209,  26]],
#
#        [[210,  26]],
#
#        [[211,  25]],
#
#        [[214,  25]],
#
#        [[215,  24]],
#
#        [[217,  24]],
#
#        [[218,  23]],
#
#        [[219,  23]],
#
#        [[220,  22]]], dtype=int32), array([[[79, 20]],
#
#        [[80, 20]],
#
#        [[82, 22]],
#
#        [[82, 23]],
#
#        [[80, 25]],
#
#        [[80, 26]],
#
#        [[79, 27]],
#
#        [[79, 28]],
#
#        [[77, 30]],
#
#        [[77, 31]],
#
#        [[76, 32]],
#
#        [[75, 31]],
#
#        [[75, 28]],
#
#        [[76, 27]],
#
#        [[76, 25]],
#
#        [[77, 24]],
#
#        [[77, 22]]], dtype=int32), array([[[233,  19]],
#
#        [[234,  18]],
#
#        [[235,  19]],
#
#        [[234,  20]]], dtype=int32), array([[[586,  18]],
#
#        [[587,  17]],
#
#        [[588,  18]],
#
#        [[587,  19]]], dtype=int32), array([[[573,  18]],
#
#        [[574,  17]],
#
#        [[575,  17]],
#
#        [[576,  18]],
#
#        [[575,  19]],
#
#        [[574,  19]]], dtype=int32), array([[[561,  17]],
#
#        [[562,  16]],
#
#        [[563,  16]],
#
#        [[564,  17]],
#
#        [[563,  18]],
#
#        [[562,  18]]], dtype=int32), array([[[540,  17]]], dtype=int32), array([[[229,  17]],
#
#        [[230,  16]],
#
#        [[231,  17]],
#
#        [[230,  18]]], dtype=int32), array([[[75, 17]],
#
#        [[76, 16]],
#
#        [[78, 16]],
#
#        [[79, 17]],
#
#        [[78, 18]],
#
#        [[76, 18]]], dtype=int32), array([[[585,  16]],
#
#        [[586,  15]],
#
#        [[587,  16]],
#
#        [[586,  17]]], dtype=int32), array([[[577,  16]],
#
#        [[578,  15]],
#
#        [[579,  16]],
#
#        [[578,  17]]], dtype=int32), array([[[489,  16]],
#
#        [[490,  15]],
#
#        [[491,  16]],
#
#        [[490,  17]]], dtype=int32), array([[[449,  16]],
#
#        [[450,  15]],
#
#        [[451,  16]],
#
#        [[451,  17]],
#
#        [[450,  18]],
#
#        [[449,  17]]], dtype=int32), array([[[445,  16]],
#
#        [[446,  15]],
#
#        [[447,  16]],
#
#        [[446,  17]]], dtype=int32), array([[[515,  15]],
#
#        [[516,  14]],
#
#        [[517,  14]],
#
#        [[518,  15]],
#
#        [[517,  16]],
#
#        [[516,  16]]], dtype=int32), array([[[78, 15]],
#
#        [[79, 14]],
#
#        [[80, 15]],
#
#        [[79, 16]]], dtype=int32), array([[[520,  14]],
#
#        [[521,  13]],
#
#        [[522,  14]],
#
#        [[521,  15]]], dtype=int32), array([[[518,  14]],
#
#        [[519,  13]],
#
#        [[520,  14]],
#
#        [[519,  15]]], dtype=int32), array([[[490,  13]],
#
#        [[491,  12]],
#
#        [[492,  13]],
#
#        [[491,  14]]], dtype=int32), array([[[516,  12]],
#
#        [[517,  11]],
#
#        [[518,  11]],
#
#        [[519,  12]],
#
#        [[519,  13]],
#
#        [[518,  14]]], dtype=int32), array([[[488,  12]],
#
#        [[489,  11]],
#
#        [[490,  12]],
#
#        [[489,  13]]], dtype=int32), array([[[476,   8]],
#
#        [[477,   7]],
#
#        [[478,   7]],
#
#        [[479,   8]],
#
#        [[478,   9]],
#
#        [[477,   9]]], dtype=int32), array([[[468,   8]],
#
#        [[469,   7]],
#
#        [[470,   7]],
#
#        [[471,   8]],
#
#        [[470,   9]],
#
#        [[469,   9]]], dtype=int32), array([[[442,   8]],
#
#        [[443,   7]],
#
#        [[444,   8]],
#
#        [[444,   9]],
#
#        [[443,  10]],
#
#        [[442,   9]]], dtype=int32), array([[[62,  8]],
#
#        [[63,  7]],
#
#        [[64,  8]],
#
#        [[63,  9]]], dtype=int32), array([[[219,   7]],
#
#        [[220,   6]],
#
#        [[221,   6]],
#
#        [[222,   7]],
#
#        [[221,   8]],
#
#        [[220,   8]]], dtype=int32), array([[[60,  7]],
#
#        [[61,  6]],
#
#        [[62,  6]],
#
#        [[63,  7]],
#
#        [[62,  8]],
#
#        [[61,  8]]], dtype=int32), array([[[337,   6]],
#
#        [[338,   5]],
#
#        [[340,   5]],
#
#        [[342,   7]],
#
#        [[341,   8]],
#
#        [[339,   8]]], dtype=int32), array([[[241,   5]],
#
#        [[242,   4]],
#
#        [[243,   5]],
#
#        [[243,   6]],
#
#        [[244,   7]],
#
#        [[243,   8]],
#
#        [[242,   8]],
#
#        [[241,   7]]], dtype=int32), array([[[236,   5]],
#
#        [[237,   4]],
#
#        [[238,   5]],
#
#        [[238,   7]],
#
#        [[237,   8]],
#
#        [[236,   8]],
#
#        [[235,   7]],
#
#        [[236,   6]]], dtype=int32), array([[[0, 5]],
#
#        [[1, 4]],
#
#        [[2, 4]],
#
#        [[3, 5]],
#
#        [[3, 6]],
#
#        [[2, 7]]], dtype=int32), array([[[499,   4]],
#
#        [[500,   3]],
#
#        [[517,   3]],
#
#        [[518,   4]],
#
#        [[519,   4]],
#
#        [[520,   5]],
#
#        [[522,   5]],
#
#        [[523,   6]],
#
#        [[524,   6]],
#
#        [[525,   7]],
#
#        [[526,   7]],
#
#        [[527,   8]],
#
#        [[528,   8]],
#
#        [[530,  10]],
#
#        [[531,  10]],
#
#        [[533,  12]],
#
#        [[534,  12]],
#
#        [[537,  15]],
#
#        [[539,  15]],
#
#        [[537,  13]],
#
#        [[536,  13]],
#
#        [[535,  12]],
#
#        [[535,  11]],
#
#        [[534,  10]],
#
#        [[535,   9]],
#
#        [[537,   9]],
#
#        [[540,  12]],
#
#        [[540,  13]],
#
#        [[541,  13]],
#
#        [[542,  14]],
#
#        [[542,  15]],
#
#        [[543,  15]],
#
#        [[544,  16]],
#
#        [[544,  18]],
#
#        [[543,  19]],
#
#        [[538,  19]],
#
#        [[537,  20]],
#
#        [[534,  20]],
#
#        [[535,  21]],
#
#        [[535,  22]],
#
#        [[536,  22]],
#
#        [[538,  24]],
#
#        [[538,  23]],
#
#        [[539,  22]],
#
#        [[540,  22]],
#
#        [[542,  20]],
#
#        [[543,  20]],
#
#        [[544,  19]],
#
#        [[557,  19]],
#
#        [[558,  20]],
#
#        [[581,  20]],
#
#        [[582,  21]],
#
#        [[586,  21]],
#
#        [[588,  23]],
#
#        [[587,  24]],
#
#        [[586,  24]],
#
#        [[586,  25]],
#
#        [[581,  30]],
#
#        [[581,  31]],
#
#        [[580,  32]],
#
#        [[580,  34]],
#
#        [[579,  35]],
#
#        [[579,  36]],
#
#        [[578,  37]],
#
#        [[578,  55]],
#
#        [[579,  56]],
#
#        [[579,  57]],
#
#        [[580,  58]],
#
#        [[580,  60]],
#
#        [[581,  61]],
#
#        [[581,  63]],
#
#        [[582,  63]],
#
#        [[583,  64]],
#
#        [[583,  67]],
#
#        [[581,  69]],
#
#        [[572,  69]],
#
#        [[571,  68]],
#
#        [[570,  69]],
#
#        [[569,  69]],
#
#        [[568,  68]],
#
#        [[541,  68]],
#
#        [[540,  69]],
#
#        [[533,  69]],
#
#        [[532,  68]],
#
#        [[532,  67]],
#
#        [[533,  66]],
#
#        [[537,  66]],
#
#        [[538,  65]],
#
#        [[563,  65]],
#
#        [[564,  66]],
#
#        [[573,  66]],
#
#        [[569,  62]],
#
#        [[568,  62]],
#
#        [[563,  57]],
#
#        [[563,  56]],
#
#        [[562,  56]],
#
#        [[561,  55]],
#
#        [[561,  54]],
#
#        [[560,  54]],
#
#        [[559,  53]],
#
#        [[559,  52]],
#
#        [[548,  41]],
#
#        [[548,  40]],
#
#        [[547,  40]],
#
#        [[546,  39]],
#
#        [[546,  38]],
#
#        [[541,  33]],
#
#        [[541,  32]],
#
#        [[539,  30]],
#
#        [[538,  30]],
#
#        [[538,  35]],
#
#        [[537,  36]],
#
#        [[537,  38]],
#
#        [[536,  39]],
#
#        [[536,  42]],
#
#        [[535,  43]],
#
#        [[535,  47]],
#
#        [[534,  48]],
#
#        [[534,  53]],
#
#        [[533,  54]],
#
#        [[533,  56]],
#
#        [[532,  57]],
#
#        [[532,  60]],
#
#        [[530,  62]],
#
#        [[529,  62]],
#
#        [[528,  61]],
#
#        [[528,  59]],
#
#        [[529,  58]],
#
#        [[529,  55]],
#
#        [[530,  54]],
#
#        [[530,  51]],
#
#        [[531,  50]],
#
#        [[531,  45]],
#
#        [[532,  44]],
#
#        [[532,  40]],
#
#        [[533,  39]],
#
#        [[533,  36]],
#
#        [[534,  35]],
#
#        [[534,  32]],
#
#        [[535,  31]],
#
#        [[535,  29]],
#
#        [[536,  28]],
#
#        [[536,  26]],
#
#        [[531,  21]],
#
#        [[531,  19]],
#
#        [[532,  18]],
#
#        [[534,  18]],
#
#        [[535,  17]],
#
#        [[536,  17]],
#
#        [[535,  16]],
#
#        [[534,  16]],
#
#        [[533,  15]],
#
#        [[532,  15]],
#
#        [[530,  13]],
#
#        [[529,  13]],
#
#        [[528,  12]],
#
#        [[527,  12]],
#
#        [[525,  10]],
#
#        [[524,  10]],
#
#        [[523,   9]],
#
#        [[522,   9]],
#
#        [[521,   8]],
#
#        [[520,   8]],
#
#        [[519,   7]],
#
#        [[517,   7]],
#
#        [[516,   6]],
#
#        [[499,   6]],
#
#        [[498,   7]],
#
#        [[497,   7]],
#
#        [[496,   8]],
#
#        [[492,   8]],
#
#        [[490,  10]],
#
#        [[489,  10]],
#
#        [[488,  11]],
#
#        [[486,  11]],
#
#        [[484,  13]],
#
#        [[483,  13]],
#
#        [[480,  16]],
#
#        [[479,  16]],
#
#        [[480,  17]],
#
#        [[481,  17]],
#
#        [[482,  16]],
#
#        [[486,  16]],
#
#        [[487,  17]],
#
#        [[489,  17]],
#
#        [[490,  18]],
#
#        [[490,  22]],
#
#        [[488,  24]],
#
#        [[488,  26]],
#
#        [[487,  27]],
#
#        [[487,  29]],
#
#        [[486,  30]],
#
#        [[486,  34]],
#
#        [[485,  35]],
#
#        [[485,  52]],
#
#        [[486,  53]],
#
#        [[486,  54]],
#
#        [[485,  55]],
#
#        [[485,  60]],
#
#        [[484,  61]],
#
#        [[475,  61]],
#
#        [[474,  62]],
#
#        [[473,  61]],
#
#        [[471,  61]],
#
#        [[470,  62]],
#
#        [[458,  62]],
#
#        [[457,  63]],
#
#        [[453,  63]],
#
#        [[452,  64]],
#
#        [[449,  64]],
#
#        [[448,  65]],
#
#        [[447,  65]],
#
#        [[446,  66]],
#
#        [[444,  66]],
#
#        [[443,  67]],
#
#        [[442,  66]],
#
#        [[442,  64]],
#
#        [[443,  63]],
#
#        [[444,  63]],
#
#        [[445,  62]],
#
#        [[448,  62]],
#
#        [[449,  61]],
#
#        [[451,  61]],
#
#        [[452,  60]],
#
#        [[458,  60]],
#
#        [[459,  59]],
#
#        [[468,  59]],
#
#        [[469,  58]],
#
#        [[482,  58]],
#
#        [[481,  57]],
#
#        [[482,  56]],
#
#        [[482,  34]],
#
#        [[483,  33]],
#
#        [[483,  28]],
#
#        [[484,  27]],
#
#        [[484,  26]],
#
#        [[485,  25]],
#
#        [[485,  24]],
#
#        [[486,  23]],
#
#        [[486,  22]],
#
#        [[487,  21]],
#
#        [[487,  19]],
#
#        [[478,  19]],
#
#        [[477,  20]],
#
#        [[472,  20]],
#
#        [[471,  21]],
#
#        [[465,  21]],
#
#        [[464,  22]],
#
#        [[457,  22]],
#
#        [[456,  23]],
#
#        [[452,  23]],
#
#        [[451,  24]],
#
#        [[450,  24]],
#
#        [[449,  25]],
#
#        [[448,  24]],
#
#        [[448,  22]],
#
#        [[450,  20]],
#
#        [[455,  20]],
#
#        [[456,  19]],
#
#        [[466,  19]],
#
#        [[467,  18]],
#
#        [[471,  18]],
#
#        [[472,  17]],
#
#        [[476,  17]],
#
#        [[476,  16]],
#
#        [[478,  14]],
#
#        [[478,  13]],
#
#        [[480,  11]],
#
#        [[481,  11]],
#
#        [[483,   9]],
#
#        [[485,   9]],
#
#        [[487,   7]],
#
#        [[489,   7]],
#
#        [[490,   6]],
#
#        [[491,   6]],
#
#        [[492,   5]],
#
#        [[494,   5]],
#
#        [[495,   4]]], dtype=int32), array([[[786,   2]],
#
#        [[787,   1]],
#
#        [[788,   2]],
#
#        [[792,   2]],
#
#        [[794,   4]],
#
#        [[793,   5]],
#
#        [[793,   6]],
#
#        [[791,   8]],
#
#        [[788,   8]],
#
#        [[787,   7]],
#
#        [[788,   6]],
#
#        [[789,   6]],
#
#        [[790,   5]],
#
#        [[786,   5]],
#
#        [[786,   6]],
#
#        [[785,   7]],
#
#        [[784,   7]],
#
#        [[783,   6]],
#
#        [[783,   4]],
#
#        [[785,   2]]], dtype=int32), array([[[526,   2]],
#
#        [[527,   1]],
#
#        [[528,   2]],
#
#        [[527,   3]]], dtype=int32), array([[[522,   2]],
#
#        [[523,   1]],
#
#        [[524,   2]],
#
#        [[523,   3]]], dtype=int32), array([[[498,   2]],
#
#        [[499,   1]],
#
#        [[500,   1]],
#
#        [[501,   2]],
#
#        [[500,   3]],
#
#        [[499,   3]]], dtype=int32), array([[[792,   1]],
#
#        [[793,   0]],
#
#        [[796,   0]],
#
#        [[797,   1]],
#
#        [[796,   2]],
#
#        [[793,   2]]], dtype=int32), array([[[780,   1]],
#
#        [[781,   0]],
#
#        [[782,   0]],
#
#        [[783,   1]],
#
#        [[782,   2]],
#
#        [[781,   2]]], dtype=int32), array([[[519,   1]],
#
#        [[520,   0]],
#
#        [[521,   0]],
#
#        [[522,   1]],
#
#        [[521,   2]],
#
#        [[520,   2]]], dtype=int32), array([[[491,   1]],
#
#        [[492,   0]],
#
#        [[495,   0]],
#
#        [[496,   1]],
#
#        [[495,   2]],
#
#        [[492,   2]]], dtype=int32), array([[[  0,   0]],
#
#        [[  0, 454]],
#
#        [[  2, 454]],
#
#        [[  3, 455]],
#
#        [[  2, 456]],
#
#        [[  0, 456]],
#
#        [[  0, 460]],
#
#        [[  1, 461]],
#
#        [[  1, 463]],
#
#        [[  0, 464]],
#
#        [[  0, 465]],
#
#        [[808, 465]],
#
#        [[808, 168]],
#
#        [[807, 167]],
#
#        [[808, 166]],
#
#        [[808, 157]],
#
#        [[807, 157]],
#
#        [[806, 158]],
#
#        [[806, 159]],
#
#        [[807, 160]],
#
#        [[807, 161]],
#
#        [[808, 162]],
#
#        [[808, 164]],
#
#        [[807, 165]],
#
#        [[803, 161]],
#
#        [[803, 158]],
#
#        [[802, 157]],
#
#        [[798, 157]],
#
#        [[797, 156]],
#
#        [[796, 156]],
#
#        [[795, 157]],
#
#        [[794, 156]],
#
#        [[794, 154]],
#
#        [[795, 153]],
#
#        [[797, 153]],
#
#        [[798, 154]],
#
#        [[801, 154]],
#
#        [[802, 155]],
#
#        [[803, 155]],
#
#        [[804, 154]],
#
#        [[805, 154]],
#
#        [[805, 153]],
#
#        [[806, 152]],
#
#        [[807, 152]],
#
#        [[808, 151]],
#
#        [[808,  20]],
#
#        [[807,  20]],
#
#        [[806,  21]],
#
#        [[802,  21]],
#
#        [[801,  20]],
#
#        [[800,  20]],
#
#        [[796,  16]],
#
#        [[796,  10]],
#
#        [[797,   9]],
#
#        [[797,   8]],
#
#        [[800,   5]],
#
#        [[801,   5]],
#
#        [[802,   4]],
#
#        [[805,   4]],
#
#        [[806,   5]],
#
#        [[807,   5]],
#
#        [[808,   6]],
#
#        [[806,   8]],
#
#        [[802,   8]],
#
#        [[800,  10]],
#
#        [[800,  11]],
#
#        [[799,  12]],
#
#        [[799,  13]],
#
#        [[801,  15]],
#
#        [[801,  16]],
#
#        [[802,  17]],
#
#        [[807,  17]],
#
#        [[808,  16]],
#
#        [[808,  14]],
#
#        [[806,  16]],
#
#        [[804,  16]],
#
#        [[803,  15]],
#
#        [[803,  14]],
#
#        [[805,  12]],
#
#        [[803,  10]],
#
#        [[804,   9]],
#
#        [[806,   9]],
#
#        [[807,  10]],
#
#        [[807,  11]],
#
#        [[808,  12]],
#
#        [[808,   2]],
#
#        [[805,   2]],
#
#        [[804,   1]],
#
#        [[805,   0]],
#
#        [[808,   0]],
#
#        [[802,   0]],
#
#        [[801,   1]],
#
#        [[800,   1]],
#
#        [[799,   0]],
#
#        [[517,   0]],
#
#        [[516,   1]],
#
#        [[515,   0]],
#
#        [[456,   0]],
#
#        [[455,   1]],
#
#        [[454,   1]],
#
#        [[453,   0]],
#
#        [[437,   0]],
#
#        [[437,   3]],
#
#        [[436,   4]],
#
#        [[435,   3]],
#
#        [[435,   0]],
#
#        [[318,   0]],
#
#        [[318,   1]],
#
#        [[317,   2]],
#
#        [[315,   0]],
#
#        [[305,   0]],
#
#        [[304,   1]],
#
#        [[303,   0]],
#
#        [[120,   0]],
#
#        [[120,   2]],
#
#        [[118,   4]],
#
#        [[116,   2]],
#
#        [[116,   0]]], dtype=int32)] [[[   1   -1   -1   -1]
#   [   2    0   -1   -1]
#   [   3    1   -1   -1]
#   ...
#   [1005 1003   -1   -1]
#   [1006 1004   -1   -1]
#   [  -1 1005   -1   -1]]]
